# %% [markdown]
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# [Module Title]: [Topic]\n",
#     "\n",
#     "**Course**: End-to-End Machine Learning (Datacamp)  \n",
#     "**Case Study**: CardioCare Heart Disease Prediction  \n",
#     "**Author**: Seif\n",
#     "\n",
#     "---\n",
#     "\n",
#     "## Overview\n",
#     "\n",
#     "Use this template for each exercise notebook. Update the metadata at the top and keep the following sections:\n",
#     "\n",
#     "1. Problem/Exercise description\n",
#     "2. Imports and environment\n",
#     "3. Data loading\n",
#     "4. Exploratory Data Analysis (EDA)\n",
#     "5. Data preprocessing\n",
#     "6. Modeling\n",
#     "7. Evaluation\n",
#     "8. Key takeaways\n",
#     "    \n",
#     "---"
#    ]
#   }

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %matplotlib inline
